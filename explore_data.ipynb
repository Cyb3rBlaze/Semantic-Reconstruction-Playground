# %%
import nibabel as nib

import h5py

import matplotlib.pyplot as plt

# %%
img = nib.load("./dataset_train/sub-UTS01/ses-1/func/sub-UTS01_ses-1_task-AttendFemaleSpeaker_bold.nii.gz")

# width, length, height, time
img.shape
# Out:
# (84, 84, 54, 187)

# %%
np_data = img.get_fdata()
plt.imshow(np_data[:, :, 20, 30])

# %%
with h5py.File("./dataset_train/derivative/preprocessed_data/UTS01/adollshouse.hf5", "r") as f:
    ds_arr = f["data"][()]  # returns as a numpy array

# temporal dim, channel dim
ds_arr.shape
# Out:
# (241, 81126)
